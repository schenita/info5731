# %% [markdown]
# <a href="https://colab.research.google.com/github/schenita/info5731/blob/master/Class_WalleVsDoraemon.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/wshuyi/demo-image-classification-fastai.git
# Out:
# Cloning into 'demo-image-classification-fastai'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 382 (delta 0), reused 0 (delta 0), pack-reused 379
# Receiving objects: 100% (382/382), 52.42 MiB | 24.48 MiB/s, done.
# Resolving deltas: 100% (3/3), done.

# %%
from fastai.vision import *

# %%
path = Path("demo-image-classification-fastai/imgs/")

# %%
data = ImageDataBunch.from_folder(path, test='test', size=224)

# %%
data.show_batch(rows=3, figsize=(10, 10))

# %%
learn = cnn_learner(data, models.resnet18, metrics=accuracy)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet18-5c106cde.pth" to /root/.torch/models/resnet18-5c106cde.pth
# 46827520it [00:03, 15330587.93it/s]

# %%
learn.fit_one_cycle(1)
# Out:
# Total time: 00:11 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.633436</td>
#       <td>0.104387</td>
#       <td>0.969697</td>
#       <td>00:11</td>
#     </tr>
#   </tbody>
# </table>

# %%
interp = ClassificationInterpretation.from_learner(learn)

# %%
interp.plot_top_losses(9, figsize=(8, 8))

# %%
interp.plot_confusion_matrix()

# %%
img = learn.data.test_ds[0][0]

# %%
img
# Out:
# Image (3, 224, 224)

# %%
learn.predict(img)
# Out:
# (Category doraemon, tensor(0), tensor([0.6925, 0.3075]))

# %%
img = learn.data.valid_ds[0][0]

# %%
img
# Out:
# Image (3, 224, 224)

# %%
learn.predict(img)
# Out:
# (Category walle, tensor(1), tensor([0.0108, 0.9892]))

# %%
# !pip install google_images_download
# Out:
# Collecting google_images_download
#   Downloading https://files.pythonhosted.org/packages/43/51/49ebfd3a02945974b1d93e34bb96a1f9530a0dde9c2bc022b30fd658edd6/google_images_download-2.5.0.tar.gz
# Collecting selenium (from google_images_download)
#   Downloading https://files.pythonhosted.org/packages/80/d6/4294f0b4bce4de0abf13e17190289f9d0613b0a44e5dd6a7f5ca98459853/selenium-3.141.0-py2.py3-none-any.whl (904kB)
#     100% |████████████████████████████████| 911kB 16.8MB/s
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.6/dist-packages (from selenium->google_images_download) (1.22)
# Building wheels for collected packages: google-images-download
#   Building wheel for google-images-download (setup.py) ... done
#   Stored in directory: /root/.cache/pip/wheels/d2/23/84/3cec6d566b88bef64ad727a7e805f6544b8af4a8f121f9691c
# Successfully built google-images-download
# Installing collected packages: selenium, google-images-download
# Successfully installed google-images-download-2.5.0 selenium-3.141.0

# %%
# !pip install duckgoose
from duckgoose import fetchImagesAndPrepForClassification

# dictionary structure `class_name => search term`
image_classes = { 'ducks' : 'ducks -rubber' , 'geese' : 'geese' }
download_path = '/home/myuser/data/downloaded_from_google'
output_path = '/demo-image-classification-fastai/imgs'
number_of_images = 10

fetchImagesAndPrepForClassification(image_classes, download_path, output_path, number_of_images)
# Out:
# Requirement already satisfied: duckgoose in /usr/local/lib/python3.6/dist-packages (0.1.7)
# Requirement already satisfied: google-images-download in /usr/local/lib/python3.6/dist-packages (from duckgoose) (2.5.0)
# Requirement already satisfied: selenium in /usr/local/lib/python3.6/dist-packages (from google-images-download->duckgoose) (3.141.0)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.6/dist-packages (from selenium->google-images-download->duckgoose) (1.22)
#
# Item no.: 1 --> Item name = ducks
# Evaluating...
# Starting Download...
# Completed Image ====> ducks -rubber 1. 1200px-bucephala-albeola-010.jpg
# Completed Image ====> ducks -rubber 2. mallard-web.jpg
# Completed Image ====> ducks -rubber 3. photo-1459682687441-7761439a709d?ixlib=rb-1.2.1&ixid=eyjhchbfawqiojeymdd9&w=1000&q=80.jpg
# Completed Image ====> ducks -rubber 4. call-ducks-for-sale.jpg
# Completed Image ====> ducks -rubber 5. web_hoodedmerganser20_raise-crest_0.jpg
# Completed Image ====> ducks -rubber 6. mandarinduck-971545542.jpg
# Completed Image ====> ducks -rubber 7. duck-big-bill-59ef8e5068e1a2001072c89e.jpg
# Completed Image ====> ducks -rubber 8. 1*efjpoz8lhnkyd8xcswv2oa.jpeg
# Completed Image ====> ducks -rubber 9. nyc-mandarin-duck_holly-mascaro.jpg
# Completed Image ====> ducks -rubber 10. king-eider-5a43b2abbeba3300374797df.jpg
#
# Errors: 0
#
#
# Item no.: 1 --> Item name = geese
# Evaluating...
# Starting Download...
# Completed Image ====> geese 1. 59953131-480px.jpg
# Completed Image ====> geese 2. canadian-geese.jpg
# Completed Image ====> geese 3. telemmglpict000156477260_trans_nvbqzqnjv4bqn2n2hk5qkej--a9z8hblakoh1fqkp2ebx1ykxfpcom4.jpeg
# Completed Image ====> geese 4. north-little-rock-hunting.jpg
# Completed Image ====> geese 5. 59950681-480px.jpg
# Completed Image ====> geese 6. geese_chrissy-downunder-600x347.jpg
# Completed Image ====> geese 7. 1516932669131.jpg
# Completed Image ====> geese 8. canada-goose-2349806_960_720.jpg
# Completed Image ====> geese 9. obwogo+m.jpg
# Completed Image ====> geese 10. geese_.jpg
#
# Errors: 0
#
# Error encountered for /home/myuser/data/downloaded_from_google/ducks/ducks -rubber 41. greenwing-teal-drake-duck.jpg: cannot identify image file '/home/myuser/data/downloaded_from_google/ducks/ducks -rubber 41. greenwing-teal-drake-duck.jpg'
# Figure does not have 3 channels: /home/myuser/data/downloaded_from_google/ducks/ducks -rubber 16. ducks.jpg

# %%
path
# Out:
# PosixPath('demo-image-classification-fastai/imgs')

# %%
ls
# Out:
# demo-image-classification-fastai/  sample_data/  wall.jpeg
