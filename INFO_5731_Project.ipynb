# %% [markdown]
# <a href="https://colab.research.google.com/github/schenita/info5731/blob/master/INFO_5731_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Project using Waze Data

# %%
import pickle
import numpy as np 
import pandas as pd

# %%
dataset = pd.read_pickle('time_converted_df.pickle')
dataset.head()
# Out:
#                    EVENT_ID EVENT_STATE EVENT_CLASS  \
# 0  '2018110100002600005075'      closed    incident
# 1  '2018110100181100005075'      closed    incident
# 2  '2018110100210000005075'      closed    incident
# 3  '2018110100222500005075'      closed    incident
# 4  '2018110100234000005075'      closed    incident
#
#                     EVENT_TYPE FACILITY_NAME   DIRECTION ARTICLE_CODE  \
# 0               minor accident        I-30 E   Eastbound          NaN
# 1                        other       I-35E S  Southbound          NaN
# 2                  road closed   Warren Pkwy  Northbound          NaN
# 3  stopped car on the shoulder       I-820 E   Eastbound          NaN
# 4                  traffic jam   Warren Pkwy         NaN          NaN
#
#   FROM_LOC_POINT TO_LOC_POINT            CREATE_TIME         ...          \
# 0            NaN          NaN  11/1/2018 12:00:26 AM         ...
# 1            NaN          NaN  11/1/2018 12:18:11 AM         ...
# ...

# %%
dataset.describe()
# Out:
#                         EVENT_ID EVENT_STATE EVENT_CLASS   EVENT_TYPE  \
# count                    3077490     3077490     3077490      3077490
# unique                   2772272           2           1           32
# top     '2018120416510200005075'      closed    incident  traffic jam
# freq                           2     3077477     3077490      1651222
# first                        NaN         NaN         NaN          NaN
# last                         NaN         NaN         NaN          NaN
#
#        FACILITY_NAME   DIRECTION ARTICLE_CODE FROM_LOC_POINT TO_LOC_POINT  \
# count        3057785     1393177        60158          60158      1512668
# unique         32511           4            2            438        29436
# top           I-30 W  Northbound      between        Rowlett  Frontage Rd
# freq           59396      355635        60033           2371        49921
# first            NaN         NaN          NaN            NaN          NaN
# ...

# %%
dataset.describe(include='all')
# Out:
#                         EVENT_ID EVENT_STATE EVENT_CLASS   EVENT_TYPE  \
# count                    3077490     3077490     3077490      3077490
# unique                   2772272           2           1           32
# top     '2018120416510200005075'      closed    incident  traffic jam
# freq                           2     3077477     3077490      1651222
# first                        NaN         NaN         NaN          NaN
# last                         NaN         NaN         NaN          NaN
#
#        FACILITY_NAME   DIRECTION ARTICLE_CODE FROM_LOC_POINT TO_LOC_POINT  \
# count        3057785     1393177        60158          60158      1512668
# unique         32511           4            2            438        29436
# top           I-30 W  Northbound      between        Rowlett  Frontage Rd
# freq           59396      355635        60033           2371        49921
# first            NaN         NaN          NaN            NaN          NaN
# ...

# %%
print(dataset.shape)
# Out:
# (3077490, 26)

# %%
print(dataset.nunique())
# Out:
# EVENT_ID             2772272
# EVENT_STATE                2
# EVENT_CLASS                1
# EVENT_TYPE                32
# FACILITY_NAME          32511
# DIRECTION                  4
# ARTICLE_CODE               2
# FROM_LOC_POINT           438
# TO_LOC_POINT           29436
# CREATE_TIME          1452206
# LAST_UPDATE           241997
# CLOSE_TIME            215744
# EVENT_DESCRIPTION     905387
# CITY                     307
# COUNTY                    31
# STATE                      3
# LAT                   790549
# LON                   916648
# TO_LAT                174673
# TO_LON                187277
# START_DATE                 0
# END_DATE                   0
# INCIDENT_IMPACT            0
# UPDATE_NUMBER            627
# WAZE_EVENT_ID          40796
# time                 1452206
# dtype: int64

# %%
dataset.tail()
# Out:
#                          EVENT_ID EVENT_STATE EVENT_CLASS  \
# 3077485  '2019013123572800105075'      closed    incident
# 3077486  '2019013123572900005075'      closed    incident
# 3077487  '2019013123575400005075'      closed    incident
# 3077488  '2019013123583400005075'      closed    incident
# 3077489  '2019013123585200005075'      closed    incident
#
#                           EVENT_TYPE FACILITY_NAME   DIRECTION ARTICLE_CODE  \
# 3077485                  traffic jam  Bloomdale Rd         NaN          NaN
# 3077486                  traffic jam  John West Rd         NaN          NaN
# 3077487  stopped car on the shoulder       I-35E S  Southbound          NaN
# 3077488                  traffic jam       Coit Rd         NaN          NaN
# 3077489                  stopped car       I-635 W   Westbound          NaN
#
#         FROM_LOC_POINT            TO_LOC_POINT            CREATE_TIME  \
# 3077485            NaN             N Custer Rd  1/31/2019 11:57:28 PM
# ...

# %%
dataset.STATE.unique()
# Out:
# array(['TX', 'MS', nan, 'OK'], dtype=object)

# %%
TXdataset = dataset.loc[dataset['STATE'] == 'TX']

# %%
TXdataset.head()
# Out:
#                    EVENT_ID EVENT_STATE EVENT_CLASS  \
# 0  '2018110100002600005075'      closed    incident
# 1  '2018110100181100005075'      closed    incident
# 2  '2018110100210000005075'      closed    incident
# 3  '2018110100222500005075'      closed    incident
# 4  '2018110100234000005075'      closed    incident
#
#                     EVENT_TYPE FACILITY_NAME   DIRECTION ARTICLE_CODE  \
# 0               minor accident        I-30 E   Eastbound          NaN
# 1                        other       I-35E S  Southbound          NaN
# 2                  road closed   Warren Pkwy  Northbound          NaN
# 3  stopped car on the shoulder       I-820 E   Eastbound          NaN
# 4                  traffic jam   Warren Pkwy         NaN          NaN
#
#   FROM_LOC_POINT TO_LOC_POINT            CREATE_TIME         ...          \
# 0            NaN          NaN  11/1/2018 12:00:26 AM         ...
# 1            NaN          NaN  11/1/2018 12:18:11 AM         ...
# ...

# %%
print(TXdataset.nunique())
# Out:
# EVENT_ID             2772260
# EVENT_STATE                2
# EVENT_CLASS                1
# EVENT_TYPE                32
# FACILITY_NAME          32511
# DIRECTION                  4
# ARTICLE_CODE               2
# FROM_LOC_POINT           438
# TO_LOC_POINT           29436
# CREATE_TIME          1452198
# LAST_UPDATE           241997
# CLOSE_TIME            215744
# EVENT_DESCRIPTION     905375
# CITY                     305
# COUNTY                    31
# STATE                      1
# LAT                   790547
# LON                   916646
# TO_LAT                174673
# TO_LON                187277
# START_DATE                 0
# END_DATE                   0
# INCIDENT_IMPACT            0
# UPDATE_NUMBER            627
# WAZE_EVENT_ID          40796
# time                 1452198
# dtype: int64

# %%
TXdataset.EVENT_STATE.unique()
# Out:
# array(['closed', 'updated'], dtype=object)

# %%
TXdataset.describe()
# Out:
#                         EVENT_ID EVENT_STATE EVENT_CLASS   EVENT_TYPE  \
# count                    3077478     3077478     3077478      3077478
# unique                   2772260           2           1           32
# top     '2018120416510200005075'      closed    incident  traffic jam
# freq                           2     3077465     3077478      1651222
# first                        NaN         NaN         NaN          NaN
# last                         NaN         NaN         NaN          NaN
#
#        FACILITY_NAME   DIRECTION ARTICLE_CODE FROM_LOC_POINT TO_LOC_POINT  \
# count        3057774     1393165        60158          60158      1512668
# unique         32511           4            2            438        29436
# top           I-30 W  Northbound      between        Rowlett  Frontage Rd
# freq           59396      355631        60033           2371        49921
# first            NaN         NaN          NaN            NaN          NaN
# ...

# %%
TXdataset.STATE.unique()
# Out:
# array(['TX'], dtype=object)

# %%
print(dataset.shape)
# Out:
# (3077490, 26)

# %%
print(TXdataset.shape)
# Out:
# (3077478, 26)

# %%
TXdataset.COUNTY.unique()
# Out:
# array(['Dallas', 'Collin', 'Tarrant', 'Denton', 'Hill', 'Parker', 'Ellis',
#        'Kaufman', 'Van Zandt', 'Hunt', 'Navarro', 'Rockwall', 'Johnson',
#        'Henderson', 'Hopkins', 'Wise', 'Palo Pinto', 'Grayson', 'Hood',
#        'Jack', 'Erath', 'Bosque', 'Somervell', 'Rains', 'Young', 'Fannin',
#        'Comanche', 'Delta', 'Eastland', 'Archer', 'Montague'],
#       dtype=object)

# %%
COUNTYdataset = dataset[dataset["COUNTY"].isin(["Dallas" , "Collin" , "Tarrant" , "Denton" , "Somervell" , "Parker" , "Ellis" , "Kaufman" , "Hunt" , "Rockwall" , "Johnson" , "Wise" , "Hood"])]

# %%
print(COUNTYdataset.shape)
# Out:
# (3026028, 26)

# %%
COUNTY5dataset = dataset[dataset["COUNTY"].isin(["Dallas" , "Collin" , "Tarrant" , "Denton" , "Parker" ])]

# %%
print(COUNTY5dataset.shape)
# Out:
# (2796653, 26)

# %%
Dentondataset = dataset[dataset["COUNTY"].isin(["Denton"])]

# %%
print(Dentondataset.shape)
# Out:
# (279005, 26)

# %%
Dallasdataset = dataset[dataset["COUNTY"].isin(["Dallas"])]

# %%
print(Dallasdataset.shape)
# Out:
# (1345065, 26)
